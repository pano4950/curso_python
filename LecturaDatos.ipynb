# %%
import numpy as np
np.random.seed(1)
d = {"A":np.random.binomial(10,0.5,5),
     "B":np.random.binomial(10,0.5,5),
     "C":np.random.binomial(10,0.5,5)
     }
d
# Out:
# {'A': array([5, 6, 0, 4, 3]),
#  'B': array([3, 4, 4, 5, 5]),
#  'C': array([5, 6, 4, 7, 2])}

# %%
import pandas as pd
pf= pd.DataFrame(d)
pf
# Out:
#    A  B  C
# 0  5  3  5
# 1  6  4  6
# 2  0  4  4
# 3  4  5  7
# 4  3  5  2

# %%
pf[["A","C"]]
# Out:
#    A  C
# 0  5  5
# 1  6  6
# 2  0  4
# 3  4  7
# 4  3  2

# %%
#Escoger fila
pf.iloc[0:4:2]
# Out:
#    A  B  C
# 0  5  3  5
# 2  0  4  4

# %%
pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
pf.describe()
#La estadística descriptiva de los datos.
# Out:
#               A        B         C
# count  5.000000  5.00000  5.000000
# mean   3.600000  4.20000  4.800000
# std    2.302173  0.83666  1.923538
# min    0.000000  3.00000  2.000000
# 25%    3.000000  4.00000  4.000000
# 50%    4.000000  4.00000  5.000000
# 75%    5.000000  5.00000  6.000000
# max    6.000000  5.00000  7.000000

# %%
print(pf["A"][0])
# Out:
# 5

# %%
ssma= pf.read_csv("Wine dataset.csv")
print (ssma)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-15-576077400.py in <cell line: 0>()
# ----> 1 ssma= pf.read_csv("Wine dataset.csv")
#       2 print (ssma)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
